# %% [markdown]
# # Heart Disease Prediction — Master Project Notebook
#
# This is the shared master notebook. Each student adds their section here
# once it is finished and tested in their personal sandbox folder.
#
# **Rule:** Only ONE person edits this file at a time.
# Pull before you open it. Push immediately when you are done.
#
# ## Sections
# - Step 1: Business Understanding
# - Step 2: Data Understanding (EDA)
# - Step 3: Data Preparation
# - Step 4: Modelling
# - Step 5: Evaluation
